# %%
import openweathermapy.core as owm
import pandas as pd
import requests 
from citipy import citipy
import matplotlib.pyplot as plt
from config import api_key
import time
import urllib
import random
import numpy as np
import seaborn as sns
output_data_file = "output_data/cities.csv"

# %%
cities = "cities.csv"
cities_df = pd.read_csv(cities)
cities_df.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000   1.516667
# 1      ad           canillo  42.566667   1.600000
# 2      ad            encamp  42.533333   1.583333
# 3      ad        la massana  42.550000   1.516667
# 4      ad      les escaldes  42.500000   1.533333

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %%
i=0

for city in cities_df:
    print(city)
    i=i+1

print("city count"+str(i))
# Out:
# Country
# City
# Latitude
# Longitude
# city count4

# %%
#url
url = "http://api.openweathermap.org/data/2.5/weather?"
city = cities_df.City
city.head()
# Out:
# 0    andorra la vella
# 1             canillo
# 2              encamp
# 3          la massana
# 4        les escaldes
# Name: City, dtype: object

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb'

# %%
city=city
query_url = url+"appid="+api_key+"&q="+ city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("--X--X--X--")
print("Data Retrieval Complete")
print("--X--X--X--")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# Processing Record 2 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta%20arenas
# Processing Record 3 of Set 1 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tukrah
# City not found. Skipping...
# Processing Record 4 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kodiak
# Processing Record 5 of Set 1 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount%20gambier
# Processing Record 6 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mataura
# Processing Record 7 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# Processing Record 8 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=georgetown
# Processing Record 9 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# Processing Record 10 of Set 1 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=westport
# Processing Record 11 of Set 1 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kalmunai
# Processing Record 12 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=thompson
# Processing Record 13 of Set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alofi
# Processing Record 14 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# Processing Record 15 of Set 1 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oistins
# Processing Record 16 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# Processing Record 17 of Set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# Processing Record 18 of Set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde%20river
# Processing Record 19 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# Processing Record 20 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dikson
# Processing Record 21 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=riyadh
# Processing Record 23 of Set 1 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nantucket
# Processing Record 24 of Set 1 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hare%20bay
# Processing Record 25 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=arraial%20do%20cabo
# Processing Record 26 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hermanus
# Processing Record 27 of Set 1 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marystown
# Processing Record 28 of Set 1 | xinyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=xinyang
# Processing Record 29 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=souillac
# Processing Record 30 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# Processing Record 31 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pevek
# Processing Record 32 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# Processing Record 33 of Set 1 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lakes%20entrance
# Processing Record 34 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# Processing Record 35 of Set 1 | zagare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zagare
# Processing Record 36 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=quatre%20cocos
# Processing Record 38 of Set 1 | fengzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fengzhen
# Processing Record 39 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto%20ayora
# Processing Record 40 of Set 1 | potiskum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=potiskum
# Processing Record 41 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# Processing Record 42 of Set 1 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tessalit
# Processing Record 43 of Set 1 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yaan
# Processing Record 44 of Set 1 | palmares do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palmares%20do%20sul
# Processing Record 45 of Set 1 | kharian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kharian
# Processing Record 46 of Set 1 | nikki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nikki
# Processing Record 47 of Set 1 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sakakah
# City not found. Skipping...
# Processing Record 48 of Set 1 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=champerico
# Processing Record 49 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bambous%20virieux
# Processing Record 50 of Set 1 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=whitehorse
# Processing Record 0 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# Processing Record 2 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# Processing Record 3 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# Processing Record 4 of Set 2 | ascension
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ascension
# City not found. Skipping...
# Processing Record 5 of Set 2 | ozgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ozgon
# City not found. Skipping...
# Processing Record 6 of Set 2 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mecca
# Processing Record 7 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=flinders
# Processing Record 8 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanortalik
# Processing Record 9 of Set 2 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tevaitoa
# Processing Record 10 of Set 2 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havre-saint-pierre
# Processing Record 11 of Set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oussouye
# Processing Record 13 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=new%20norfolk
# Processing Record 14 of Set 2 | milove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=milove
# Processing Record 15 of Set 2 | agaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=agaro
# Processing Record 16 of Set 2 | bismarck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bismarck
# Processing Record 17 of Set 2 | pavlodar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pavlodar
# Processing Record 18 of Set 2 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=caucaia
# Processing Record 19 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chuy
# Processing Record 20 of Set 2 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=husavik
# Processing Record 21 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20alfred
# Processing Record 22 of Set 2 | of
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=of
# City not found. Skipping...
# Processing Record 23 of Set 2 | horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=horsham
# Processing Record 24 of Set 2 | bulungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bulungu
# Processing Record 25 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=luderitz
# Processing Record 26 of Set 2 | sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sindor
# Processing Record 27 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# Processing Record 28 of Set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faya
# Processing Record 29 of Set 2 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palmer
# Processing Record 30 of Set 2 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambilobe
# Processing Record 31 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nikolskoye
# Processing Record 32 of Set 2 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=shache
# Processing Record 33 of Set 2 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=grootfontein
# Processing Record 34 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# Processing Record 35 of Set 2 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 2 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuuk
# Processing Record 37 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port-gentil
# Processing Record 38 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape%20town
# Processing Record 39 of Set 2 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sungaipenuh
# Processing Record 40 of Set 2 | minot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=minot
# Processing Record 41 of Set 2 | nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nacala
# Processing Record 42 of Set 2 | lukiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lukiv
# Processing Record 43 of Set 2 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao%20joao%20da%20barra
# Processing Record 44 of Set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ribeira%20grande
# Processing Record 45 of Set 2 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=faanui
# Processing Record 47 of Set 2 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=linxia
# Processing Record 48 of Set 2 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=farafangana
# Processing Record 49 of Set 2 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=naze
# Processing Record 0 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=provideniya
# Processing Record 1 of Set 3 | iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iralaya
# Processing Record 2 of Set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ancud
# Processing Record 3 of Set 3 | mvuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mvuma
# Processing Record 4 of Set 3 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand%20centre
# City not found. Skipping...
# Processing Record 5 of Set 3 | kawana waters
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kawana%20waters
# City not found. Skipping...
# Processing Record 6 of Set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=abu%20kamal
# Processing Record 8 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=castro
# Processing Record 9 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iqaluit
# Processing Record 10 of Set 3 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nemuro
# Processing Record 11 of Set 3 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coahuayana
# Processing Record 12 of Set 3 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=monrovia
# Processing Record 13 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=adrar
# Processing Record 14 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# Processing Record 15 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | razole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=razole
# Processing Record 17 of Set 3 | vredendal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vredendal
# Processing Record 18 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hithadhoo
# Processing Record 19 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=upernavik
# Processing Record 20 of Set 3 | rosetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rosetown
# Processing Record 21 of Set 3 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=egvekinot
# Processing Record 22 of Set 3 | mallapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mallapuram
# Processing Record 23 of Set 3 | tranby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tranby
# Processing Record 24 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lompoc
# Processing Record 25 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fortuna
# Processing Record 26 of Set 3 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=itoman
# Processing Record 27 of Set 3 | cesis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cesis
# Processing Record 28 of Set 3 | ust-uda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ust-uda
# Processing Record 29 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar%20del%20plata
# Processing Record 30 of Set 3 | venice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=venice
# Processing Record 31 of Set 3 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20hardy
# Processing Record 32 of Set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=leningradskiy
# Processing Record 33 of Set 3 | kommunisticheskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kommunisticheskiy
# Processing Record 34 of Set 3 | ventersburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ventersburg
# Processing Record 35 of Set 3 | cap-aux-meules
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cap-aux-meules
# Processing Record 36 of Set 3 | alakurtti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alakurtti
# Processing Record 37 of Set 3 | jieshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jieshi
# Processing Record 38 of Set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=severo-kurilsk
# Processing Record 39 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=college
# Processing Record 40 of Set 3 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bur%20gabo
# City not found. Skipping...
# Processing Record 41 of Set 3 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rawson
# Processing Record 42 of Set 3 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=burnie
# Processing Record 43 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# Processing Record 44 of Set 3 | karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=karasjok
# Processing Record 45 of Set 3 | nanyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanyang
# Processing Record 46 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# Processing Record 47 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=butaritari
# Processing Record 48 of Set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lagoa
# Processing Record 49 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebu
# Processing Record 0 of Set 4 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hami
# Processing Record 1 of Set 4 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=karratha
# Processing Record 2 of Set 4 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yar-sale
# Processing Record 3 of Set 4 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=isangel
# Processing Record 4 of Set 4 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=high%20level
# Processing Record 5 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=talnakh
# Processing Record 6 of Set 4 | pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pedernales
# Processing Record 7 of Set 4 | beian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beian
# Processing Record 8 of Set 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=geraldton
# Processing Record 9 of Set 4 | argentan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=argentan
# Processing Record 10 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# Processing Record 11 of Set 4 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=shingu
# Processing Record 12 of Set 4 | dakoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dakoro
# Processing Record 13 of Set 4 | masalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=masalli
# Processing Record 14 of Set 4 | lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lodja
# Processing Record 15 of Set 4 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sioux%20lookout
# Processing Record 16 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuatapere
# Processing Record 17 of Set 4 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=virginia%20beach
# Processing Record 18 of Set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20elizabeth
# Processing Record 19 of Set 4 | lafia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lafia
# Processing Record 20 of Set 4 | bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bandar
# Processing Record 21 of Set 4 | berekum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berekum
# Processing Record 22 of Set 4 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mackenzie
# Processing Record 23 of Set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=srednekolymsk
# Processing Record 24 of Set 4 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhuhai
# Processing Record 25 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# Processing Record 26 of Set 4 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mogadishu
# Processing Record 27 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# Processing Record 28 of Set 4 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20quintin
# Processing Record 29 of Set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=constitucion
# Processing Record 30 of Set 4 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=praia
# Processing Record 31 of Set 4 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavaratti
# Processing Record 33 of Set 4 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sorland
# Processing Record 34 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# Processing Record 35 of Set 4 | liuzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=liuzhou
# Processing Record 36 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cidreira
# Processing Record 37 of Set 4 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=asyut
# Processing Record 38 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20lincoln
# Processing Record 39 of Set 4 | usingen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=usingen
# Processing Record 40 of Set 4 | gobo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=gobo
# Processing Record 41 of Set 4 | bimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bimbo
# Processing Record 42 of Set 4 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=meyungs
# City not found. Skipping...
# Processing Record 43 of Set 4 | bolobo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bolobo
# Processing Record 44 of Set 4 | bisert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bisert
# Processing Record 45 of Set 4 | maloy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maloy
# Processing Record 46 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# Processing Record 47 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilulissat
# Processing Record 48 of Set 4 | adelaide
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=adelaide
# Processing Record 49 of Set 4 | ituporanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ituporanga
# Processing Record 0 of Set 5 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=le%20port
# Processing Record 1 of Set 5 | ganzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ganzhou
# Processing Record 2 of Set 5 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=inirida
# Processing Record 3 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lorengau
# Processing Record 4 of Set 5 | santa maria del oro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=santa%20maria%20del%20oro
# Processing Record 5 of Set 5 | havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havre
# Processing Record 6 of Set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bethel
# Processing Record 7 of Set 5 | rabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rabat
# Processing Record 8 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ahipara
# Processing Record 9 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cap%20malheureux
# Processing Record 10 of Set 5 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount%20isa
# Processing Record 11 of Set 5 | rajura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rajura
# Processing Record 12 of Set 5 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chicama
# Processing Record 13 of Set 5 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# Processing Record 14 of Set 5 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beloha
# Processing Record 15 of Set 5 | kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kayerkan
# Processing Record 16 of Set 5 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=yerbogachen
# Processing Record 17 of Set 5 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavieng
# Processing Record 18 of Set 5 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=opuwo
# Processing Record 19 of Set 5 | urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=urengoy
# Processing Record 20 of Set 5 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila%20franca%20do%20campo
# Processing Record 21 of Set 5 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=namatanai
# Processing Record 22 of Set 5 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# Processing Record 23 of Set 5 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lima
# Processing Record 24 of Set 5 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=padang
# Processing Record 25 of Set 5 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vanimo
# Processing Record 26 of Set 5 | melo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=melo
# Processing Record 27 of Set 5 | riverton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=riverton
# Processing Record 28 of Set 5 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=anadyr
# Processing Record 29 of Set 5 | jackson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jackson
# Processing Record 30 of Set 5 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ust-nera
# Processing Record 31 of Set 5 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=xining
# Processing Record 33 of Set 5 | rimini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rimini
# Processing Record 34 of Set 5 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=umm%20lajj
# Processing Record 35 of Set 5 | creel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=creel
# Processing Record 36 of Set 5 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=broome
# Processing Record 37 of Set 5 | mol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mol
# Processing Record 38 of Set 5 | sidi bu zayd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sidi%20bu%20zayd
# City not found. Skipping...
# Processing Record 39 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saldanha
# Processing Record 40 of Set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nome
# Processing Record 41 of Set 5 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=la%20ronge
# Processing Record 42 of Set 5 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuhan
# Processing Record 43 of Set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint%20george
# Processing Record 44 of Set 5 | swan hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=swan%20hill
# Processing Record 45 of Set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=codrington
# Processing Record 46 of Set 5 | vitkov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vitkov
# Processing Record 47 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=namibe
# Processing Record 48 of Set 5 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuan
# Processing Record 49 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bengkulu
# City not found. Skipping...
# Processing Record 0 of Set 6 | pirai do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pirai%20do%20sul
# Processing Record 1 of Set 6 | carmaux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=carmaux
# Processing Record 2 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila%20velha
# Processing Record 3 of Set 6 | kisii
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kisii
# Processing Record 4 of Set 6 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=necochea
# Processing Record 5 of Set 6 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=satitoa
# City not found. Skipping...
# Processing Record 6 of Set 6 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta%20delgada
# Processing Record 7 of Set 6 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushtobe
# Processing Record 8 of Set 6 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jacareacanga
# Processing Record 9 of Set 6 | ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ayr
# Processing Record 10 of Set 6 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aklavik
# Processing Record 11 of Set 6 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 6 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=havoysund
# Processing Record 13 of Set 6 | bajo baudo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bajo%20baudo
# City not found. Skipping...
# Processing Record 14 of Set 6 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coos%20bay
# Processing Record 15 of Set 6 | araucaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=araucaria
# Processing Record 16 of Set 6 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=honiara
# Processing Record 18 of Set 6 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=paamiut
# Processing Record 19 of Set 6 | baker city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=baker%20city
# Processing Record 20 of Set 6 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ranong
# Processing Record 21 of Set 6 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oranjemund
# Processing Record 22 of Set 6 | colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=colares
# Processing Record 23 of Set 6 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 6 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# Processing Record 25 of Set 6 | macusani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=macusani
# Processing Record 26 of Set 6 | itanagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=itanagar
# Processing Record 27 of Set 6 | iwanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iwanai
# Processing Record 28 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alice%20springs
# Processing Record 29 of Set 6 | tungkang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tungkang
# City not found. Skipping...
# Processing Record 30 of Set 6 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tasiilaq
# Processing Record 31 of Set 6 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=taltal
# Processing Record 32 of Set 6 | narwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=narwar
# Processing Record 33 of Set 6 | kuala terengganu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuala%20terengganu
# Processing Record 34 of Set 6 | burley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=burley
# Processing Record 35 of Set 6 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=east%20london
# Processing Record 36 of Set 6 | banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=banjar
# Processing Record 37 of Set 6 | dzerzhinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dzerzhinskoye
# Processing Record 38 of Set 6 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=quelimane
# Processing Record 39 of Set 6 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | daugavpils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=daugavpils
# Processing Record 42 of Set 6 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lata
# Processing Record 43 of Set 6 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=oktyabrskoye
# Processing Record 44 of Set 6 | son la
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=son%20la
# Processing Record 45 of Set 6 | aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aginskoye
# Processing Record 46 of Set 6 | tandil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tandil
# Processing Record 47 of Set 6 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=atar
# Processing Record 48 of Set 6 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kitimat
# Processing Record 49 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman%20wells
# Processing Record 0 of Set 7 | samarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=samarkand
# Processing Record 1 of Set 7 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kieta
# Processing Record 2 of Set 7 | cianorte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cianorte
# Processing Record 3 of Set 7 | manacor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=manacor
# Processing Record 4 of Set 7 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 7 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pontianak
# Processing Record 6 of Set 7 | cabo san lucas
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=behshahr
# Processing Record 37 of Set 11 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sibolga
# Processing Record 38 of Set 11 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ukiah
# Processing Record 39 of Set 11 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maniitsoq
# Processing Record 40 of Set 11 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=broken%20hill
# Processing Record 41 of Set 11 | baoding
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=baoding
# Processing Record 42 of Set 11 | nata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nata
# Processing Record 43 of Set 11 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tres%20arroyos
# Processing Record 44 of Set 11 | olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=olga
# Processing Record 45 of Set 11 | jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jabiru
# City not found. Skipping...
# Processing Record 46 of Set 11 | chimoio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chimoio
# Processing Record 47 of Set 11 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20patricio
# Processing Record 49 of Set 11 | valkeakoski
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=valkeakoski
# Processing Record 0 of Set 12 | fraserburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=fraserburgh
# Processing Record 1 of Set 12 | kholmogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kholmogory
# Processing Record 2 of Set 12 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=camacha
# Processing Record 3 of Set 12 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=beringovskiy
# Processing Record 4 of Set 12 | kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kroya
# Processing Record 5 of Set 12 | jennings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jennings
# Processing Record 6 of Set 12 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=port%20shepstone
# Processing Record 7 of Set 12 | bridlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bridlington
# Processing Record 8 of Set 12 | villazon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=villazon
# City not found. Skipping...
# Processing Record 9 of Set 12 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=lincoln
# Processing Record 10 of Set 12 | anori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=anori
# Processing Record 11 of Set 12 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=rocha
# Processing Record 12 of Set 12 | cajuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cajuru
# Processing Record 13 of Set 12 | goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=goure
# Processing Record 14 of Set 12 | esna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=esna
# Processing Record 15 of Set 12 | mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mocuba
# Processing Record 16 of Set 12 | alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=alotau
# City not found. Skipping...
# Processing Record 17 of Set 12 | vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vytegra
# Processing Record 18 of Set 12 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=cayenne
# Processing Record 19 of Set 12 | stolin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=stolin
# Processing Record 20 of Set 12 | pudozh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pudozh
# Processing Record 21 of Set 12 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto%20escondido
# Processing Record 22 of Set 12 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuching
# Processing Record 23 of Set 12 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kalianget
# Processing Record 24 of Set 12 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coihaique
# Processing Record 25 of Set 12 | doaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=doaba
# Processing Record 26 of Set 12 | guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=guarapari
# Processing Record 27 of Set 12 | brazzaville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=brazzaville
# Processing Record 28 of Set 12 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kenora
# Processing Record 29 of Set 12 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chernyshevskiy
# Processing Record 30 of Set 12 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=iquique
# Processing Record 31 of Set 12 | villa guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=villa%20guerrero
# Processing Record 32 of Set 12 | killin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=killin
# Processing Record 33 of Set 12 | san marcos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20marcos
# Processing Record 34 of Set 12 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ishigaki
# Processing Record 35 of Set 12 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sechura
# Processing Record 36 of Set 12 | canguaretama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=canguaretama
# Processing Record 37 of Set 12 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint%20anthony
# Processing Record 38 of Set 12 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dunedin
# Processing Record 39 of Set 12 | priiskovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=priiskovyy
# Processing Record 40 of Set 12 | falmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=falmouth
# Processing Record 41 of Set 12 | dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dzhebariki-khaya
# Processing Record 42 of Set 12 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=vestmannaeyjar
# Processing Record 43 of Set 12 | ambunti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ambunti
# Processing Record 44 of Set 12 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nara
# Processing Record 45 of Set 12 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=emba
# Processing Record 46 of Set 12 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=san%20jose
# Processing Record 47 of Set 12 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaqortoq
# Processing Record 48 of Set 12 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 12 | aldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aldan
# Processing Record 0 of Set 13 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=marawi
# Processing Record 1 of Set 13 | nonantola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nonantola
# Processing Record 2 of Set 13 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=tezu
# Processing Record 3 of Set 13 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=phan%20thiet
# Processing Record 4 of Set 13 | trofors
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=trofors
# Processing Record 5 of Set 13 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=turukhansk
# Processing Record 6 of Set 13 | aketi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=aketi
# Processing Record 7 of Set 13 | katiola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=katiola
# Processing Record 8 of Set 13 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=maldonado
# Processing Record 9 of Set 13 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sinnamary
# Processing Record 10 of Set 13 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=brae
# Processing Record 11 of Set 13 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 13 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=berlevag
# Processing Record 13 of Set 13 | illela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=illela
# Processing Record 14 of Set 13 | mondlo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=mondlo
# Processing Record 15 of Set 13 | wad madani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=wad%20madani
# City not found. Skipping...
# Processing Record 16 of Set 13 | hinton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hinton
# Processing Record 17 of Set 13 | ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ginda
# Processing Record 18 of Set 13 | chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=chikoy
# City not found. Skipping...
# Processing Record 19 of Set 13 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=coquimbo
# Processing Record 20 of Set 13 | kirensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kirensk
# Processing Record 21 of Set 13 | hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=hailar
# Processing Record 22 of Set 13 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=victor%20harbor
# Processing Record 23 of Set 13 | ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ouadda
# Processing Record 24 of Set 13 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=guerrero%20negro
# Processing Record 25 of Set 13 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=ust-tsilma
# Processing Record 26 of Set 13 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=honningsvag
# Processing Record 27 of Set 13 | nieuw amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=nieuw%20amsterdam
# Processing Record 28 of Set 13 | pemalang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=pemalang
# Processing Record 29 of Set 13 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=peniche
# Processing Record 30 of Set 13 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=bowen
# Processing Record 31 of Set 13 | jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=jasper
# Processing Record 32 of Set 13 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=dong%20hoi
# Processing Record 33 of Set 13 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=clarence%20town
# Processing Record 34 of Set 13 | kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kijang
# Processing Record 35 of Set 13 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=innisfail
# Processing Record 36 of Set 13 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=luanda
# Processing Record 37 of Set 13 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb&q=kahului
# --X--X--X--
# Data Retrieval Complete
# --X--X--X--

# %%
# #500+ cities across the world of varying distance from the equator
# listoflatitudelongitude = []
# n = 501
# for i in range(0,n):
#     coordinate = ( random.randint(-18000.00,18000.00)/100,  random.randint(-9000.00,9000.00)/100 )
#     listoflatitudelongitude.append(coordinate)
# cities_list = []
# cities_dict = {}
# for x in listoflatitudelongitude:
#     print ( x[0] )
#     print( x[1])
#     if (citipy.nearest_city(x[1],x[0]) != ""):
#         city_name_str = str(citipy.nearest_city(x[1],x[0]).city_name)
#         cities_list.append(city_name_str)
#         cities_dict.__setitem__(city_name_str, x )

# %%
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Humidity      575
# Lat           575
# Lng           575
# Max Temp      575
# Wind Speed    575
# dtype: int64

# %%
#scatter plot for latitude vs temperatur
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig1.png")

plt.show()

# %%
#scatter plots for each city types
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig2.png")

plt.show()

# %%
# scatter plots for each city types
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig3.png")

plt.show()

# %%
#scatter plots for each city types
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("City Latitude vs. Wind Speed" )
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig4.png")

plt.show()
